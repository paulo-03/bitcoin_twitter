# %%
#Imports
import pandas as pd
import numpy as np
from helpers.data_analysis import TweetsAnalyzer, BTCAnalyzer

# %%
start_time = pd.Timestamp('2017-08-17 04:00:00+00:00')
end_time = pd.Timestamp('2019-11-23 14:00:20+00:00')
print(start_time- end_time)
# Out:
# -829 days +13:59:40

# %% [markdown]
# ## BTC

# %%
# BTC data loading
btc_clean = BTCAnalyzer(file_path='clean_data/btc.parquet')
# Out:
# ########## Basic information ##########
# - Shape of dataset: (46028, 2)
# - Average time granularity: 0 days 01:00:00
# - Data starting from 2017-08-17 04:00:00+00:00 to 2022-11-16 23:00:00+00:00
# - Data Types of each column:
# close      float32
# returns    float32
# dtype: object

# %%
df_btc=btc_clean.data
df_btc = df_btc.loc[start_time:end_time]
df_btc
# Out:
#                                  close   returns
# open_time
# 2017-08-17 04:00:00+00:00  4308.830078       NaN
# 2017-08-17 05:00:00+00:00  4315.319824  0.001506
# 2017-08-17 06:00:00+00:00  4324.350098  0.002093
# 2017-08-17 07:00:00+00:00  4349.990234  0.005929
# 2017-08-17 08:00:00+00:00  4360.689941  0.002460
# ...                                ...       ...
# 2019-11-23 10:00:00+00:00  7165.169922  0.001634
# 2019-11-23 11:00:00+00:00  7171.919922  0.000942
# 2019-11-23 12:00:00+00:00  7150.140137 -0.003037
# 2019-11-23 13:00:00+00:00  7170.310059  0.002821
# 2019-11-23 14:00:00+00:00  7256.379883  0.012004
#
# [19883 rows x 2 columns]

# %%
#check the date
# Ensure the 'open_time' column is in datetime format
# Ensure the index is in datetime format
df_btc.index = pd.to_datetime(df_btc.index)

# Create a complete range of hourly timestamps
full_range = pd.date_range(start=df_btc.index.min(), end=df_btc.index.max(), freq='h')

# Find missing timestamps
missing_hours = full_range.difference(df_btc.index)

# Print the missing hours
print(f"Missing hours: {missing_hours}")
# Out:
# Missing hours: DatetimeIndex([], dtype='datetime64[ns, UTC]', freq='h')

# %%
# Checking the number of returns that are less than 0.001 because I need to determine the threshold for the neutral label
df_btc[np.abs(df_btc['returns'])<=0.001].shape
# Out:
# (3819, 8)

# %%
# Function to apply a label using the returns
def label_btc(returns, threshold):
    if returns > threshold:
        return 'BULLISH'
    elif returns < -threshold:
        return 'BEARISH'
    else:
        return 'NEUTRAL'

# %%
# Apply the label te each hour
df_btc['label'] = df_btc['returns'].apply(lambda x: label_btc(x, 0.001))
mapping = {'BEARISH':0,'NEUTRAL': 1,'BULLISH': 2}
df_btc['final_label'] = df_btc['label'].map(mapping)
df_btc
# Out:
# C:\Users\ratas\AppData\Local\Temp\ipykernel_4816\1285183844.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_btc['label'] = df_btc['returns'].apply(lambda x: label_btc(x, 0.001))
# C:\Users\ratas\AppData\Local\Temp\ipykernel_4816\1285183844.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_btc['final_label'] = df_btc['label'].map(mapping)
#                                   open         high          low        close  \
# open_time
# 2017-08-17 04:00:00+00:00  4261.479980  4313.620117  4261.319824  4308.830078
# 2017-08-17 05:00:00+00:00  4308.830078  4328.689941  4291.370117  4315.319824
# 2017-08-17 06:00:00+00:00  4315.319824  4345.450195  4309.370117  4324.350098
# 2017-08-17 07:00:00+00:00  4324.350098  4349.990234  4287.410156  4349.990234
# 2017-08-17 08:00:00+00:00  4333.319824  4377.850098  4333.319824  4360.689941
# ...                                ...          ...          ...          ...
# 2019-11-23 10:00:00+00:00  7151.560059  7199.990234  7114.279785  7165.169922
# 2019-11-23 11:00:00+00:00  7166.379883  7215.000000  7149.220215  7171.919922
# 2019-11-23 12:00:00+00:00  7171.919922  7197.229980  7139.750000  7150.140137
# 2019-11-23 13:00:00+00:00  7150.140137  7180.000000  7147.160156  7170.310059
# 2019-11-23 14:00:00+00:00  7170.140137  7298.000000  7162.759766  7256.379883
#
#                                 volume  quote_asset_volume  number_of_trades  \
# open_time
# 2017-08-17 04:00:00+00:00    47.181007        2.023661e+05               171
# 2017-08-17 05:00:00+00:00    23.234917        1.003048e+05               102
# 2017-08-17 06:00:00+00:00     7.229691        3.128231e+04                36
# 2017-08-17 07:00:00+00:00     4.443249        1.924106e+04                25
# 2017-08-17 08:00:00+00:00     0.972807        4.239503e+03                28
# ...                                ...                 ...               ...
# 2019-11-23 10:00:00+00:00  2282.374512        1.634108e+07             19421
# 2019-11-23 11:00:00+00:00  2215.600586        1.591635e+07             18431
# 2019-11-23 12:00:00+00:00  2049.657715        1.469170e+07             19657
# 2019-11-23 13:00:00+00:00  2223.157471        1.592306e+07             15647
# 2019-11-23 14:00:00+00:00  4340.594727        3.141421e+07             30869
#
#                             returns    label  final_label
# open_time
# 2017-08-17 04:00:00+00:00       NaN  NEUTRAL            1
# 2017-08-17 05:00:00+00:00  0.001506  BULLISH            2
# 2017-08-17 06:00:00+00:00  0.002093  BULLISH            2
# 2017-08-17 07:00:00+00:00  0.005929  BULLISH            2
# 2017-08-17 08:00:00+00:00  0.002460  BULLISH            2
# ...                             ...      ...          ...
# 2019-11-23 10:00:00+00:00  0.001634  BULLISH            2
# 2019-11-23 11:00:00+00:00  0.000942  NEUTRAL            1
# 2019-11-23 12:00:00+00:00 -0.003037  BEARISH            0
# 2019-11-23 13:00:00+00:00  0.002821  BULLISH            2
# 2019-11-23 14:00:00+00:00  0.012004  BULLISH            2
#
# [19788 rows x 10 columns]

# %%
# Checking the distribution of the labels
print(df_btc.shape)
df_btc['label'].value_counts()
# Out:
# (19788, 10)
# label
# BULLISH    8187
# BEARISH    7781
# NEUTRAL    3820
# Name: count, dtype: int64

# %% [markdown]
# ## Twitter

# %%
# Loading the twitter data
twitter_clean = TweetsAnalyzer(file_path='clean_data/twitter.parquet')
df_twitter=twitter_clean.data
df_twitter.set_index('timestamp', inplace = True)
df_twitter = df_twitter.loc[start_time:end_time]
# Out:
# ########## Basic information ##########
# - Shape of dataset: (59326, 14)
# - Data starting from 2009-01-11 03:33:52+00:00 to 2019-11-23 14:00:20+00:00
# - Data Types of each column:
# index                            int64
# id                             float64
# user                            object
# fullname                        object
# url                             object
# timestamp          datetime64[ns, UTC]
# replies                          int64
# likes                            int64
# retweets                         int64
# text                            object
# cleaned_text                    object
# lang                            object
# sentiment                       object
# sentiment_score                float64
# dtype: object

# %%
df_twitter
# Out:
#                               index            id           user  \
# timestamp
# 2017-08-17 05:03:00+00:00   2843339  8.980777e+17    VivoBitcoin
# 2017-08-17 14:01:19+00:00   8190436  8.981830e+17         BitPay
# 2017-08-17 16:07:47+00:00  11453726  8.982148e+17     blockchain
# 2017-08-18 13:15:08+00:00  13966462  8.985337e+17      AngeloBTC
# 2017-08-18 18:55:49+00:00    450744  8.986497e+17  BrianRoemmele
# ...                             ...           ...            ...
# 2019-11-23 11:55:10+00:00  16879539  1.198208e+18    qhfofficial
# 2019-11-23 12:38:31+00:00  16881465  1.198219e+18     matt_odell
# 2019-11-23 12:41:58+00:00  16881483  1.198220e+18   CryptoMichNL
# 2019-11-23 13:49:46+00:00  16884388  1.198237e+18       ToneVays
# 2019-11-23 14:00:20+00:00  16889675  1.198240e+18        danheld
#
#                                                       fullname  \
# timestamp
# 2017-08-17 05:03:00+00:00                         Vivo Bitcoin
# 2017-08-17 14:01:19+00:00                               BitPay
# 2017-08-17 16:07:47+00:00                           Blockchain
# 2017-08-18 13:15:08+00:00                            Angelo฿TC
# 2017-08-18 18:55:49+00:00                       Brian Roemmele
# ...                                                        ...
# 2019-11-23 11:55:10+00:00          Quantum Hedge Fund Official
# 2019-11-23 12:38:31+00:00                           Matt Odell
# 2019-11-23 12:41:58+00:00                       Crypto Michaël
# 2019-11-23 13:49:46+00:00  Tone Vays [Bali - Financial Summit]
# 2019-11-23 14:00:20+00:00                             Dan Hedl
#
#                                                               url  replies  \
# timestamp
# 2017-08-17 05:03:00+00:00  /VivoBitcoin/status/898077687771803648        5
# 2017-08-17 14:01:19+00:00                                    None      140
# 2017-08-17 16:07:47+00:00                                    None       54
# 2017-08-18 13:15:08+00:00                                    None        2
# 2017-08-18 18:55:49+00:00                                    None        1
# ...                                                           ...      ...
# 2019-11-23 11:55:10+00:00                                    None        0
# 2019-11-23 12:38:31+00:00                                    None        8
# 2019-11-23 12:41:58+00:00                                    None        9
# 2019-11-23 13:49:46+00:00                                    None       12
# 2019-11-23 14:00:20+00:00                                    None       16
#
#                            likes  retweets  \
# timestamp
# 2017-08-17 05:03:00+00:00     44       203
# 2017-08-17 14:01:19+00:00     97        51
# 2017-08-17 16:07:47+00:00    480       243
# 2017-08-18 13:15:08+00:00    134        15
# 2017-08-18 18:55:49+00:00    366       167
# ...                          ...       ...
# 2019-11-23 11:55:10+00:00    101        14
# 2019-11-23 12:38:31+00:00    119        27
# 2019-11-23 12:41:58+00:00    149        45
# 2019-11-23 13:49:46+00:00    117        16
# 2019-11-23 14:00:20+00:00    305        64
#
#                                                                         text  \
# timestamp
# 2017-08-17 05:03:00+00:00  #BTC 24hr Summary:\nLast: $4310.00\nHigh: $439...
# 2017-08-17 14:01:19+00:00  What Bitcore Users Need to Know To Be Ready fo...
# 2017-08-17 16:07:47+00:00  Ether has arrived. Seamlessly store, send, rec...
# 2017-08-18 13:15:08+00:00  I currently have no bias on $BTC. However, I a...
# 2017-08-18 18:55:49+00:00  BOOM! \n\nBitcoin Cash BCH $645.15🚀\n\nMiners ...
# ...                                                                      ...
# 2019-11-23 11:55:10+00:00  📣Remind you📣\n\nThere are two2️⃣ days left unt...
# 2019-11-23 12:38:31+00:00  The world is ready for sats to be the standard...
# 2019-11-23 12:41:58+00:00  $BTC #BITCOIN\n\nAll in all, the long-term tre...
# 2019-11-23 13:49:46+00:00  Trading #Bitcoin - Looks like the short term l...
# 2019-11-23 14:00:20+00:00  Now is a great time to buy Bitcoin: \n\n- Neve...
#
#                                                                 cleaned_text  \
# timestamp
# 2017-08-17 05:03:00+00:00  btc 24hr summary: last: $4310.00 high: $4397.0...
# 2017-08-17 14:01:19+00:00  what bitcore users need to know to be ready fo...
# 2017-08-17 16:07:47+00:00  ether has arrived. seamlessly store, send, rec...
# 2017-08-18 13:15:08+00:00  i currently have no bias on $btc. however, i a...
# 2017-08-18 18:55:49+00:00  boom! bitcoin cash bch $645.15🚀 miners are mak...
# ...                                                                      ...
# 2019-11-23 11:55:10+00:00  📣remind you📣 there are two2️⃣ days left until ...
# 2019-11-23 12:38:31+00:00  the world is ready for sats to be the standard...
# 2019-11-23 12:41:58+00:00  $btc bitcoin all in all, the long-term trend i...
# 2019-11-23 13:49:46+00:00  trading bitcoin - looks like the short term lo...
# 2019-11-23 14:00:20+00:00  now is a great time to buy bitcoin: - never lo...
#
#                           lang sentiment  sentiment_score
# timestamp
# 2017-08-17 05:03:00+00:00   en   NEUTRAL         0.659304
# 2017-08-17 14:01:19+00:00   en   NEUTRAL         0.924089
# 2017-08-17 16:07:47+00:00   en   BULLISH         0.838789
# 2017-08-18 13:15:08+00:00   en   BULLISH         0.480497
# 2017-08-18 18:55:49+00:00   en   BULLISH         0.993328
# ...                        ...       ...              ...
# 2019-11-23 11:55:10+00:00   en   BULLISH         0.984112
# 2019-11-23 12:38:31+00:00   en   BULLISH         0.861456
# 2019-11-23 12:41:58+00:00   en   BULLISH         0.984184
# 2019-11-23 13:49:46+00:00   en   BULLISH         0.503751
# 2019-11-23 14:00:20+00:00   en   BULLISH         0.992790
#
# [58608 rows x 13 columns]

# %%
# Checking the distribution of the sentiment
print(df_twitter['sentiment'].value_counts())
print(df_twitter.groupby('sentiment')['sentiment_score'].mean())
print(df_twitter.shape)
# Out:
# sentiment
# BULLISH    26143
# BEARISH    16299
# NEUTRAL    16166
# Name: count, dtype: int64
# sentiment
# BEARISH    0.834565
# BULLISH    0.803431
# NEUTRAL    0.770533
# Name: sentiment_score, dtype: float64
# (58608, 13)

# %%
# Number of unique hours in the dataset
h = df_twitter
h['time'] = pd.to_datetime(df_twitter.index).floor('h')
print(h['time'].nunique())
# Out:
# 10579
# C:\Users\ratas\AppData\Local\Temp\ipykernel_4816\1508761858.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   h['time'] = pd.to_datetime(df_twitter.index).floor('h')

# %%
def label(rate, threshold):
    if rate > threshold:
        return 'BULLISH'
    elif rate < -threshold:
        return 'BEARISH'
    else:
        return 'NEUTRAL'

def weighted_score(tweets, granularity='h'):
    mapped_sentiment = {'BEARISH': -1, 'NEUTRAL': 0, 'BULLISH': 1}
    tweets.loc[:, 'mapped_sentiment'] = tweets['sentiment'].map(mapped_sentiment)
    tweets.loc[:, 'weighted_sentiment'] = tweets['mapped_sentiment'] * tweets['sentiment_score']
    tweets.loc[:, 'counts'] = 1
    tweets = tweets.resample(granularity).agg({
        'weighted_sentiment': 'mean',
        'counts': 'sum'
    }).dropna()
    tweets['final_sentiment'] = tweets['weighted_sentiment'].apply(lambda x: label(x, 0.33))
    return tweets
"""
def apply_label(tweet):
    if tweet['counts'] < 5:
        return label(tweet['weighted_sentiment'], 0.16)
    else:
        return label(tweet['weighted_sentiment'], 0.33)

def label_sentiment(tweets):
    tweets.loc[:,'final_sentiment'] = tweets.apply(apply_label, axis=1)
"""
tweets_ts = weighted_score(df_twitter)
#label_sentiment(Tweets_TS)
tweets_ts
# Out:
# C:\Users\ratas\AppData\Local\Temp\ipykernel_4816\383515743.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets.loc[:, 'mapped_sentiment'] = tweets['sentiment'].map(mapped_sentiment)
# C:\Users\ratas\AppData\Local\Temp\ipykernel_4816\383515743.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets.loc[:, 'weighted_sentiment'] = tweets['mapped_sentiment'] * tweets['sentiment_score']
# C:\Users\ratas\AppData\Local\Temp\ipykernel_4816\383515743.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets.loc[:, 'counts'] = 1
#                            weighted_sentiment  counts final_sentiment
# timestamp
# 2017-08-17 05:00:00+00:00            0.000000       1         NEUTRAL
# 2017-08-17 14:00:00+00:00            0.000000       1         NEUTRAL
# 2017-08-17 16:00:00+00:00            0.838789       1         BULLISH
# 2017-08-18 13:00:00+00:00            0.480497       1         BULLISH
# 2017-08-18 18:00:00+00:00            0.993328       1         BULLISH
# ...                                       ...     ...             ...
# 2019-11-23 10:00:00+00:00            0.510216       3         BULLISH
# 2019-11-23 11:00:00+00:00            0.454179       3         BULLISH
# 2019-11-23 12:00:00+00:00            0.922820       2         BULLISH
# 2019-11-23 13:00:00+00:00            0.503751       1         BULLISH
# 2019-11-23 14:00:00+00:00            0.992790       1         BULLISH
#
# [10579 rows x 3 columns]

# %%
# Checking the distribution of the final sentiment
print(tweets_ts['final_sentiment'].value_counts())
print(tweets_ts['final_sentiment'].value_counts().sum())
# Out:
# final_sentiment
# NEUTRAL    5927
# BULLISH    3302
# BEARISH    1350
# Name: count, dtype: int64
# 10579

# %%
# Mapping 0 -> Bearish, 1 -> Neutral, 2 -> Bullish
mapping = {'BEARISH': 0,'NEUTRAL': 1,'BULLISH': 2}
tweets_ts['final_sentiment'] = tweets_ts['final_sentiment'].map(mapping)
tweets_ts
# Out:
#                            weighted_sentiment  counts  final_sentiment
# timestamp
# 2017-08-17 05:00:00+00:00            0.000000       1                1
# 2017-08-17 14:00:00+00:00            0.000000       1                1
# 2017-08-17 16:00:00+00:00            0.838789       1                2
# 2017-08-18 13:00:00+00:00            0.480497       1                2
# 2017-08-18 18:00:00+00:00            0.993328       1                2
# ...                                       ...     ...              ...
# 2019-11-23 10:00:00+00:00            0.510216       3                2
# 2019-11-23 11:00:00+00:00            0.454179       3                2
# 2019-11-23 12:00:00+00:00            0.922820       2                2
# 2019-11-23 13:00:00+00:00            0.503751       1                2
# 2019-11-23 14:00:00+00:00            0.992790       1                2
#
# [10579 rows x 3 columns]

# %%
(tweets_ts['weighted_sentiment']==0).sum()
# Out:
# np.int64(1454)

# %%
# Merging the two datasets
merged_df = df_btc.merge(tweets_ts, left_index=True, right_index=True, how='left')
merged_df
# Out:
#                                   open         high          low        close  \
# open_time
# 2017-08-17 04:00:00+00:00  4261.479980  4313.620117  4261.319824  4308.830078
# 2017-08-17 05:00:00+00:00  4308.830078  4328.689941  4291.370117  4315.319824
# 2017-08-17 06:00:00+00:00  4315.319824  4345.450195  4309.370117  4324.350098
# 2017-08-17 07:00:00+00:00  4324.350098  4349.990234  4287.410156  4349.990234
# 2017-08-17 08:00:00+00:00  4333.319824  4377.850098  4333.319824  4360.689941
# ...                                ...          ...          ...          ...
# 2019-11-23 10:00:00+00:00  7151.560059  7199.990234  7114.279785  7165.169922
# 2019-11-23 11:00:00+00:00  7166.379883  7215.000000  7149.220215  7171.919922
# 2019-11-23 12:00:00+00:00  7171.919922  7197.229980  7139.750000  7150.140137
# 2019-11-23 13:00:00+00:00  7150.140137  7180.000000  7147.160156  7170.310059
# 2019-11-23 14:00:00+00:00  7170.140137  7298.000000  7162.759766  7256.379883
#
#                                 volume  quote_asset_volume  number_of_trades  \
# open_time
# 2017-08-17 04:00:00+00:00    47.181007        2.023661e+05               171
# 2017-08-17 05:00:00+00:00    23.234917        1.003048e+05               102
# 2017-08-17 06:00:00+00:00     7.229691        3.128231e+04                36
# 2017-08-17 07:00:00+00:00     4.443249        1.924106e+04                25
# 2017-08-17 08:00:00+00:00     0.972807        4.239503e+03                28
# ...                                ...                 ...               ...
# 2019-11-23 10:00:00+00:00  2282.374512        1.634108e+07             19421
# 2019-11-23 11:00:00+00:00  2215.600586        1.591635e+07             18431
# 2019-11-23 12:00:00+00:00  2049.657715        1.469170e+07             19657
# 2019-11-23 13:00:00+00:00  2223.157471        1.592306e+07             15647
# 2019-11-23 14:00:00+00:00  4340.594727        3.141421e+07             30869
#
#                             returns    label  final_label  weighted_sentiment  \
# open_time
# 2017-08-17 04:00:00+00:00       NaN  NEUTRAL            1                 NaN
# 2017-08-17 05:00:00+00:00  0.001506  BULLISH            2            0.000000
# 2017-08-17 06:00:00+00:00  0.002093  BULLISH            2                 NaN
# 2017-08-17 07:00:00+00:00  0.005929  BULLISH            2                 NaN
# 2017-08-17 08:00:00+00:00  0.002460  BULLISH            2                 NaN
# ...                             ...      ...          ...                 ...
# 2019-11-23 10:00:00+00:00  0.001634  BULLISH            2            0.510216
# 2019-11-23 11:00:00+00:00  0.000942  NEUTRAL            1            0.454179
# 2019-11-23 12:00:00+00:00 -0.003037  BEARISH            0            0.922820
# 2019-11-23 13:00:00+00:00  0.002821  BULLISH            2            0.503751
# 2019-11-23 14:00:00+00:00  0.012004  BULLISH            2            0.992790
#
#                            counts  final_sentiment
# open_time
# 2017-08-17 04:00:00+00:00     NaN              NaN
# 2017-08-17 05:00:00+00:00     1.0              1.0
# 2017-08-17 06:00:00+00:00     NaN              NaN
# 2017-08-17 07:00:00+00:00     NaN              NaN
# 2017-08-17 08:00:00+00:00     NaN              NaN
# ...                           ...              ...
# 2019-11-23 10:00:00+00:00     3.0              2.0
# 2019-11-23 11:00:00+00:00     3.0              2.0
# 2019-11-23 12:00:00+00:00     2.0              2.0
# 2019-11-23 13:00:00+00:00     1.0              2.0
# 2019-11-23 14:00:00+00:00     1.0              2.0
#
# [19788 rows x 13 columns]

# %%
# filling the missing values with neutral sentiment (or 1)
merged_df['final_sentiment'] = merged_df['final_sentiment'].fillna(1)
merged_df
# Out:
#                                   open         high          low        close  \
# open_time
# 2017-08-17 04:00:00+00:00  4261.479980  4313.620117  4261.319824  4308.830078
# 2017-08-17 05:00:00+00:00  4308.830078  4328.689941  4291.370117  4315.319824
# 2017-08-17 06:00:00+00:00  4315.319824  4345.450195  4309.370117  4324.350098
# 2017-08-17 07:00:00+00:00  4324.350098  4349.990234  4287.410156  4349.990234
# 2017-08-17 08:00:00+00:00  4333.319824  4377.850098  4333.319824  4360.689941
# ...                                ...          ...          ...          ...
# 2019-11-23 10:00:00+00:00  7151.560059  7199.990234  7114.279785  7165.169922
# 2019-11-23 11:00:00+00:00  7166.379883  7215.000000  7149.220215  7171.919922
# 2019-11-23 12:00:00+00:00  7171.919922  7197.229980  7139.750000  7150.140137
# 2019-11-23 13:00:00+00:00  7150.140137  7180.000000  7147.160156  7170.310059
# 2019-11-23 14:00:00+00:00  7170.140137  7298.000000  7162.759766  7256.379883
#
#                                 volume  quote_asset_volume  number_of_trades  \
# open_time
# 2017-08-17 04:00:00+00:00    47.181007        2.023661e+05               171
# 2017-08-17 05:00:00+00:00    23.234917        1.003048e+05               102
# 2017-08-17 06:00:00+00:00     7.229691        3.128231e+04                36
# 2017-08-17 07:00:00+00:00     4.443249        1.924106e+04                25
# 2017-08-17 08:00:00+00:00     0.972807        4.239503e+03                28
# ...                                ...                 ...               ...
# 2019-11-23 10:00:00+00:00  2282.374512        1.634108e+07             19421
# 2019-11-23 11:00:00+00:00  2215.600586        1.591635e+07             18431
# 2019-11-23 12:00:00+00:00  2049.657715        1.469170e+07             19657
# 2019-11-23 13:00:00+00:00  2223.157471        1.592306e+07             15647
# 2019-11-23 14:00:00+00:00  4340.594727        3.141421e+07             30869
#
#                             returns    label  final_label  weighted_sentiment  \
# open_time
# 2017-08-17 04:00:00+00:00       NaN  NEUTRAL            1                 NaN
# 2017-08-17 05:00:00+00:00  0.001506  BULLISH            2            0.000000
# 2017-08-17 06:00:00+00:00  0.002093  BULLISH            2                 NaN
# 2017-08-17 07:00:00+00:00  0.005929  BULLISH            2                 NaN
# 2017-08-17 08:00:00+00:00  0.002460  BULLISH            2                 NaN
# ...                             ...      ...          ...                 ...
# 2019-11-23 10:00:00+00:00  0.001634  BULLISH            2            0.510216
# 2019-11-23 11:00:00+00:00  0.000942  NEUTRAL            1            0.454179
# 2019-11-23 12:00:00+00:00 -0.003037  BEARISH            0            0.922820
# 2019-11-23 13:00:00+00:00  0.002821  BULLISH            2            0.503751
# 2019-11-23 14:00:00+00:00  0.012004  BULLISH            2            0.992790
#
#                            counts  final_sentiment
# open_time
# 2017-08-17 04:00:00+00:00     NaN              1.0
# 2017-08-17 05:00:00+00:00     1.0              1.0
# 2017-08-17 06:00:00+00:00     NaN              1.0
# 2017-08-17 07:00:00+00:00     NaN              1.0
# 2017-08-17 08:00:00+00:00     NaN              1.0
# ...                           ...              ...
# 2019-11-23 10:00:00+00:00     3.0              2.0
# 2019-11-23 11:00:00+00:00     3.0              2.0
# 2019-11-23 12:00:00+00:00     2.0              2.0
# 2019-11-23 13:00:00+00:00     1.0              2.0
# 2019-11-23 14:00:00+00:00     1.0              2.0
#
# [19788 rows x 13 columns]

# %%
# Checking for missing values
merged_df.isnull().sum()
# Out:
# open                     0
# high                     0
# low                      0
# close                    0
# volume                   0
# quote_asset_volume       0
# number_of_trades         0
# returns                  1
# label                    0
# final_label              0
# weighted_sentiment    9244
# counts                9244
# final_sentiment          0
# dtype: int64

# %%
# Tweets time series array
tweets_time_series = merged_df['final_sentiment'].astype(int).to_numpy()
print(tweets_time_series.shape)
# Out:
# (19788,)

# %%
# BTC time series array
btc_time_series = merged_df['final_label'].astype(int).to_numpy()
print(btc_time_series.shape)
# Out:
# (19788,)

# %%
btc_time_series
# Out:
# array([1, 2, 2, ..., 0, 2, 2])

# %%
tweets_time_series
# Out:
# array([1, 1, 1, ..., 2, 2, 2])

# %%
# Saving the data
np.save('data/btc_time_series.npy', btc_time_series)
np.save('data/tweets_time_series.npy', tweets_time_series)
